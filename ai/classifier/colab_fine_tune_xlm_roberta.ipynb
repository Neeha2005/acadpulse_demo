# %% [markdown]
# # AcadPulse #12 Fine-tune XLM-RoBERTa
#
# Upload or mount the AcadPulse repo, then run these cells. The dataset must be a CSV with `text,label` columns.

# %%
# !pip install -U "transformers>=4.40" "datasets>=2.18" "evaluate>=0.4" "accelerate>=0.29" scikit-learn

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Set `PROJECT_DIR` to your AcadPulse repo folder in Drive. Put your private CSV at `ai/dataset/labeled_messages.csv`.

# %%
PROJECT_DIR = '/content/drive/MyDrive/acadpulse'
# %cd $PROJECT_DIR
# !python ai/classifier/train_xlm_roberta.py --dataset ai/dataset/labeled_messages.csv --output ai/classifier/model --epochs 3 --batch-size 8

# %%
# !ls -lah ai/classifier/model
# !cat ai/classifier/model/acadpulse_model_metadata.json
